# %% [markdown]
# # **Trabalhando com planilhas do Excel**

# %%
# Importando a biblioteca Pandas
import pandas as pd

# %%
#Leitura dos Arquivos
df1 = pd.read_excel("/content/drive/MyDrive/datasets/Aracaju.xlsx")
df2 = pd.read_excel("/content/drive/MyDrive/datasets/Fortaleza.xlsx")
df3 = pd.read_excel("/content/drive/MyDrive/datasets/Natal.xlsx")
df4 = pd.read_excel("/content/drive/MyDrive/datasets/Recife.xlsx")
df5 = pd.read_excel("/content/drive/MyDrive/datasets/Salvador.xlsx")

# %%
df5.head()
# Out:
#      Cidade       Data  Vendas  LojaID  Qtde
# 0  Salvador 2018-01-01   31.06    1037     3
# 1  Salvador 2018-01-01   19.02    1034     3
# 2  Salvador 2019-02-10  173.59    1035     3
# 3  Salvador 2019-02-10  176.34    1037     3
# 4  Salvador 2019-02-14   19.47    1037     3

# %%
#juntando os arquivos
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 224     Natal 2019-01-02  178.30    1035     3
# 80   Salvador 2019-01-01   40.24    1036     2
# 181  Salvador 2019-01-02  244.83    1037     2
# 101    Recife 2019-01-01  172.55     983     7
# 118   Aracaju 2018-01-01    3.34    1522     1

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df["LojaID"] = df["LojaID"].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df.sample(15)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde
# 38      Recife 2019-01-01  104.53    983     4
# 233      Natal 2019-01-03  172.40   1036     2
# 113     Recife 2019-03-02   38.63    980     2
# 117   Salvador 2019-03-02   39.41   1034     1
# 152      Natal 2019-01-02   20.07   1035     1
# 212   Salvador 2019-01-02   50.73   1037     3
# 66    Salvador 2019-01-01   70.20   1035     3
# 214   Salvador 2019-01-02   54.94   1036     2
# 163   Salvador 2019-01-02   17.66   1036     3
# 83   Fortaleza 2019-01-01    3.88   1002     6
# 34    Salvador 2019-01-01   36.54   1037     3
# 50       Natal 2019-03-08  324.00    854     4
# 220   Salvador 2019-01-02   42.71   1035     1
# 143   Salvador 2019-01-02   41.18   1037     2
# 91     Aracaju 2018-01-01  200.85   1522     6

# %%
# Criando a coluna receita
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08

# %%
# Caso tivese na planilha a receita mas naõ a quantidade,uma opçãoseria fazer:
# df[Receita/Vendas] = df["Receita"] / df["vendas"]

# %%
# retornando a maior recenita
df["Receita"].max()
# Out:
# 3544.0

# %%
df["Receita"].min()
# Out:
# 3.34

# %%
df.nlargest(3, "Receita")
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0    853     4   3544.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0

# %%
df.nsmallest(3, "Receita")
# Out:
#       Cidade       Data  Vendas LojaID  Qtde  Receita
# 118  Aracaju 2018-01-01    3.34   1522     1     3.34
# 65    Recife 2019-01-01    4.01    981     1     4.01
# 92     Natal 2019-01-02    4.57   1035     1     4.57

# %%
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
df.sort_values("Receita", ascending=False).head(10)
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0    853     4   3544.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0
# 30  Natal 2018-10-02   856.0    853     4   3424.0
# 41  Natal 2018-05-20   835.0    852     4   3340.0
# 38  Natal 2018-02-25   828.0    852     4   3312.0
# 10  Natal 2018-10-27   828.0    852     4   3312.0
# 69  Natal 2019-03-24   817.0    852     4   3268.0
# 62  Natal 2018-02-10   793.0    854     4   3172.0
# 52  Natal 2018-04-27   778.0    854     4   3112.0

# %% [markdown]
# ## **Trabalhando com Datas**

# %%
#transformando a coluna de data em tipo inteiro
df["Data"] = df["Data"].astype("int64")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.

# %%
df.dtypes
# Out:
# Cidade                       object
# Data                          int64
# Vendas                      float64
# LojaID                       object
# Qtde                          int64
# Receita                     float64
# Ano_Vendas                    int64
# mes_vendas                    int64
# dia_vendas                    int64
# diferenca_dias      timedelta64[ns]
# Trimestre_vendas              int64
# dtype: object

# %%
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Cidade                       object
# Data                 datetime64[ns]
# Vendas                      float64
# LojaID                       object
# Qtde                          int64
# Receita                     float64
# Ano_Vendas                    int64
# mes_vendas                    int64
# dia_vendas                    int64
# diferenca_dias      timedelta64[ns]
# Trimestre_vendas              int64
# dtype: object

# %%
# Afrupamento por ano da receita
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
# Criando uma nova coluna com o ano
df["Ano_Vendas"] = df["Data"].dt.year

# %%
df.sample(10)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Vendas  \
# 82      Recife 2019-01-01   29.55    981     6   177.30        2019
# 103      Natal 2019-01-02  191.60   1034     1   191.60        2019
# 72   Fortaleza 2019-01-01  106.72   1003     4   426.88        2019
# 231      Natal 2019-01-03   89.85   1034     2   179.70        2019
# 72       Natal 2018-05-02  612.00    854     4  2448.00        2018
# 121  Fortaleza 2019-03-02   41.55    981     3   124.65        2019
# 237   Salvador 2019-01-03   38.06   1036     3   114.18        2019
# 168      Natal 2019-01-02   20.22   1036     1    20.22        2019
# 105   Salvador 2019-01-01   32.83   1037     1    32.83        2019
# 231   Salvador 2019-01-03   89.85   1034     2   179.70        2019
#
#      mes_vendas  dia_vendas diferenca_dias  Trimestre_vendas
# 82            1           1       365 days                 1
# 103           1           2       366 days                 1
# ...

# %%
#estraindo o mes e o dia de vendas
df["mes_vendas"], df["dia_vendas"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Vendas  \
# 117  Salvador 2019-03-02   39.41   1034     1    39.41        2019
# 102    Recife 2019-01-01   96.50    982     7   675.50        2019
# 84      Natal 2019-01-02   22.99   1036     1    22.99        2019
# 237  Salvador 2019-01-03   38.06   1036     3   114.18        2019
# 106   Aracaju 2018-01-01   16.32   1520     7   114.24        2018
#
#      mes_vendas  dia_vendas diferenca_dias  Trimestre_vendas
# 117           3           2       425 days                 1
# 102           1           1       365 days                 1
# 84            1           2       366 days                 1
# 237           1           3       367 days                 1
# 106           1           1         0 days                 1

# %%
# Retornando a data mais antiga
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
# Calculando a diferença de dias 
df["diferenca_dias"] = df["Data"] - df["Data"].min()

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Vendas  \
# 139  Salvador 2019-03-02  169.01   1036     1   169.01        2019
# 101     Natal 2019-01-02   32.28   1035     3    96.84        2019
# 116   Aracaju 2018-01-01   48.44   1522     4   193.76        2018
# 116  Salvador 2019-03-02   41.78   1034     3   125.34        2019
# 82      Natal 2019-03-07  868.00    854     3  2604.00        2019
#
#      mes_vendas  dia_vendas diferenca_dias  Trimestre_vendas
# 139           3           2       425 days                 1
# 101           1           2       366 days                 1
# 116           1           1         0 days                 1
# 116           3           2       425 days                 1
# 82            3           7       430 days                 1

# %%
# criando uma coluna Trimestral
df["Trimestre_vendas"] = df["Data"].dt.quarter

# %%
df.sample(10)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Vendas  \
# 81   Fortaleza 2019-01-01   10.68   1005     1    10.68        2019
# 29       Natal 2019-03-09  646.00    854     2  1292.00        2019
# 133     Recife 2019-03-02   14.67    980     7   102.69        2019
# 14    Salvador 2019-01-12  109.01   1035     2   218.02        2019
# 40       Natal 2018-01-10  885.00    853     3  2655.00        2018
# 26       Natal 2018-07-20  370.00    853     3  1110.00        2018
# 7    Fortaleza 2019-02-11   35.50   1003     2    71.00        2019
# 68   Fortaleza 2019-01-01   85.09   1005     6   510.54        2019
# 172      Natal 2019-01-02    6.70   1035     1     6.70        2019
# 27      Recife 2019-01-01   22.25    980     7   155.75        2019
#
#      mes_vendas  dia_vendas diferenca_dias  Trimestre_vendas
# 81            1           1       365 days                 1
# 29            3           9       432 days                 1
# ...

# %%
# Filtrando as vendas de 2019 do mês de março
vendas_marco_19 = df.loc[(df["Data"].dt.year == 2019) & (df["Data"].dt.month == 3)]

# %%
vendas_marco_19.sample(20)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Vendas  \
# 133     Recife 2019-03-02   14.67    980     7   102.69        2019
# 135  Fortaleza 2019-03-02   10.79    983     5    53.95        2019
# 132  Fortaleza 2019-03-02   17.49    983     5    87.45        2019
# 125     Recife 2019-03-02   37.60    983     4   150.40        2019
# 109     Recife 2019-03-02   18.90    982     6   113.40        2019
# 122     Recife 2019-03-02  235.06    983     3   705.18        2019
# 111  Fortaleza 2019-03-02    8.00    981     3    24.00        2019
# 131   Salvador 2019-03-02   63.48   1037     3   190.44        2019
# 132     Recife 2019-03-02   17.49    983     5    87.45        2019
# 2        Natal 2019-03-11  308.00    852     3   924.00        2019
# 141  Fortaleza 2019-03-02  182.75    983     8  1462.00        2019
# 119  Fortaleza 2019-03-02  152.30    982     7  1066.10        2019
# 112     Recife 2019-03-02  133.59    982     1   133.59        2019
# ...

# %% [markdown]
# ## **Visualização de dados**

# %%
df["LojaID"].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
# grafico de barras
df["LojaID"].value_counts(ascending=False).plot.bar()

# %%
# Grafico com barras Horizontais
df["LojaID"].value_counts(ascending=True).plot.barh();
# para não mostrar a linha <matplotlib.axes._subplots.AxesSubplot at 0x7f596e478690>
#adicionar ';'no final docódigo

# %%
# Grafico de pizza
df.groupby(df["Data"].dt.year)["Receita"].sum().plot.pie()

# %%
# Total de vendas por Cidade
df["Cidade"].value_counts()
# Out:
# Natal        240
# Salvador     240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
#adicionando um titulo ao grafico e alterando o nome dos eixos 
import matplotlib.pyplot as plt
df["Cidade"].value_counts().plot.bar(title= "Total de Vendas por Cidade")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas");

# %%
# Alterando a cor do Grafico
df["Cidade"].value_counts().plot.bar(title= "Total de Vendas por Cidade", color="red")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas");

# %%
# Alterando o estilo
plt.style.use("ggplot")

# %%
df.groupby(df["mes_vendas"])["Qtde"].sum().plot(title= "Total de Produtos vendidos x Mês")
plt.xlabel("Mês")
plt.ylabel("Total de Produtos Vendidos")
plt.legend()

# %%
df.groupby(df["mes_vendas"])["Qtde"].sum()
# Out:
# mes_vendas
# 1     2208
# 2      144
# 3      467
# 4       23
# 5       17
# 6       13
# 7       13
# 8        2
# 9       10
# 10      14
# 11       2
# 12       3
# Name: Qtde, dtype: int64

# %%
# Selecionando vendas de 2019
df_2019 = df[df["Ano_Vendas"] == 2019]

# %%
df_2019.groupby(df_2019["mes_vendas"])["Qtde"].sum()
# Out:
# mes_vendas
# 1    1541
# 2     128
# 3     460
# 4      12
# Name: Qtde, dtype: int64

# %%
# Total de produtos vendidos por mês
df_2019.groupby(df_2019["mes_vendas"])["Qtde"].sum().plot(marker = "o")
plt.xlabel("Mês")
plt.ylabel("Total de Produtos vendidos")
plt.legend();

# %%
# grafico Histograma
plt.hist(df["Qtde"], color="orangered");

# %%
df_2019
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Vendas  \
# 7     Aracaju 2019-01-01  172.22   1522     6  1033.32        2019
# 8     Aracaju 2019-01-01   12.16   1523     1    12.16        2019
# 9     Aracaju 2019-01-01  149.36   1523     3   448.08        2019
# 10    Aracaju 2019-01-01   42.34   1522     6   254.04        2019
# 11    Aracaju 2019-01-01  161.53   1520     4   646.12        2019
# ..        ...        ...     ...    ...   ...      ...         ...
# 235  Salvador 2019-01-03   41.84   1034     1    41.84        2019
# 236  Salvador 2019-01-03  126.29   1035     3   378.87        2019
# 237  Salvador 2019-01-03   38.06   1036     3   114.18        2019
# 238  Salvador 2019-01-03  139.64   1035     1   139.64        2019
# 239  Salvador 2019-01-03  161.41   1037     3   484.23        2019
#
#      mes_vendas  dia_vendas diferenca_dias  Trimestre_vendas
# 7             1           1       365 days                 1
# ...

# %%
plt.scatter(x=df_2019["dia_vendas"], y = df_2019["Receita"]);

# %%
# salvando os graficos em png
df_2019.groupby(df_2019["mes_vendas"])["Qtde"].sum().plot(marker= "v")
plt.title("Quantidade de Produtos Vendidos x Mês")
plt.xlabel("Mês")
plt.ylabel("Total Produtos Vendidos")
plt.legend()
plt.savefig("Graficos Qtde x MES.png")
